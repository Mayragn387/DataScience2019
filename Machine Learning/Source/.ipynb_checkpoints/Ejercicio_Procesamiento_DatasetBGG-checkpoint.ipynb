# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Modelo-predictivo-del-Boardgame-Rating" data-toc-modified-id="Modelo-predictivo-del-Boardgame-Rating-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Modelo predictivo del Boardgame Rating</a></span><ul class="toc-item"><li><span><a href="#Introducción" data-toc-modified-id="Introducción-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Introducción</a></span></li><li><span><a href="#Data-Sources" data-toc-modified-id="Data-Sources-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Data Sources</a></span></li><li><span><a href="#Libraries-&amp;-Environment" data-toc-modified-id="Libraries-&amp;-Environment-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Libraries &amp; Environment</a></span></li><li><span><a href="#Data-Pre-Processing" data-toc-modified-id="Data-Pre-Processing-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Data Pre-Processing</a></span><ul class="toc-item"><li><span><a href="#Data-Loading" data-toc-modified-id="Data-Loading-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Data Loading</a></span></li><li><span><a href="#Data-Exploration" data-toc-modified-id="Data-Exploration-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Data Exploration</a></span><ul class="toc-item"><li><span><a href="#Histogramas" data-toc-modified-id="Histogramas-1.4.2.1"><span class="toc-item-num">1.4.2.1&nbsp;&nbsp;</span>Histogramas</a></span></li></ul></li><li><span><a href="#Data-Wrangling" data-toc-modified-id="Data-Wrangling-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span>Data Wrangling</a></span></li></ul></li><li><span><a href="#Feature-Selection" data-toc-modified-id="Feature-Selection-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Feature Selection</a></span></li><li><span><a href="#Modeling" data-toc-modified-id="Modeling-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Modeling</a></span><ul class="toc-item"><li><span><a href="#Train-and-Test-Subsets-(Supervised-Learning)" data-toc-modified-id="Train-and-Test-Subsets-(Supervised-Learning)-1.6.1"><span class="toc-item-num">1.6.1&nbsp;&nbsp;</span>Train and Test Subsets (Supervised Learning)</a></span></li><li><span><a href="#Model-Selection" data-toc-modified-id="Model-Selection-1.6.2"><span class="toc-item-num">1.6.2&nbsp;&nbsp;</span>Model Selection</a></span><ul class="toc-item"><li><span><a href="#Ridge-Regularization" data-toc-modified-id="Ridge-Regularization-1.6.2.1"><span class="toc-item-num">1.6.2.1&nbsp;&nbsp;</span>Ridge Regularization</a></span></li><li><span><a href="#Lasso-Regularization" data-toc-modified-id="Lasso-Regularization-1.6.2.2"><span class="toc-item-num">1.6.2.2&nbsp;&nbsp;</span>Lasso Regularization</a></span></li></ul></li><li><span><a href="#Tuning-Parameters" data-toc-modified-id="Tuning-Parameters-1.6.3"><span class="toc-item-num">1.6.3&nbsp;&nbsp;</span>Tuning Parameters</a></span><ul class="toc-item"><li><span><a href="#Model-Metrics" data-toc-modified-id="Model-Metrics-1.6.3.1"><span class="toc-item-num">1.6.3.1&nbsp;&nbsp;</span>Model Metrics</a></span></li></ul></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Modelo predictivo del Boardgame Rating

# %% [markdown]
# * Fichero: Ejercicio_Procesamiento_DatasetBGG.ipynb
# * Autor: Mayra Goicochea Neyra
# * Fecha: 06/11/2019
# * Curso: Machine Learning
# * Nombre Proyecto: Machine Learning - Asignación 01

# %% [markdown]
# ## Introducción

# %% [markdown]
# El siguiente script de python analiza y elabora un modelo predictivo para estimar el rating de un juego de mesa basado en el dataset de BoardGamesGeek.
# El dataset incluye caracteristicas como tiempo de juego, complejidad, temática del juego, número de jugadores, número de compradores, número de intercambios del juego de mesa, reviews, entre otros.
# Se formulará un modelo de regresión lineal y se usarán técnicas de regularización.

# %% [markdown]
# ## Data Sources

# %% [markdown]
# Archivo CSV: games.csv

# %% [markdown]
# ## Libraries & Environment

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
from sklearn import linear_model, model_selection, preprocessing
from sklearn.cluster import KMeans
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.linear_model import RidgeCV, LassoCV
from sklearn.model_selection import cross_val_score, GridSearchCV
# %matplotlib inline

# %% [markdown]
# ## Data Pre-Processing

# %% [markdown]
# ### Data Loading

# %%
pathCsv = '../Data/games_detailed_info.csv'
data = pd.read_csv(pathCsv)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# Los atributos que tiene el dataset son los siguientes:

# %%
print(data.columns)
print(data.shape)
print(data.size)
# Out:
# Index(['Unnamed: 0', 'Abstract Game Rank', 'Accessory Rank', 'Amiga Rank',
#        'Arcade Rank', 'Atari ST Rank', 'Board Game Rank',
#        'Children's Game Rank', 'Commodore 64 Rank', 'Customizable Rank',
#        'Family Game Rank', 'Party Game Rank', 'RPG Item Rank',
#        'Strategy Game Rank', 'Thematic Rank', 'Video Game Rank',
#        'War Game Rank', 'alternate', 'average', 'averageweight',
#        'bayesaverage', 'boardgameartist', 'boardgamecategory',
#        'boardgamecompilation', 'boardgamedesigner', 'boardgameexpansion',
#        'boardgamefamily', 'boardgameimplementation', 'boardgameintegration',
#        'boardgamemechanic', 'boardgamepublisher', 'description', 'id', 'image',
#        'maxplayers', 'maxplaytime', 'median', 'minage', 'minplayers',
#        'minplaytime', 'numcomments', 'numweights', 'owned', 'playingtime',
#        'primary', 'stddev', 'suggested_language_dependence',
#        'suggested_num_players', 'suggested_playerage', 'thumbnail', 'trading',
#        'type', 'usersrated', 'wanting', 'wishing', 'yearpublished'],
#       dtype='object')
# (17063, 56)
# 955528

# %% [markdown]
# Se muestran los 3 primeros y 3 últimos registros.

# %%
data.head(3)
# Out:
#    Unnamed: 0  Abstract Game Rank  Accessory Rank  Amiga Rank  Arcade Rank  \
# 0           0                 NaN             NaN         NaN          NaN
# 1           1                 NaN             NaN         NaN          NaN
# 2           2                 NaN             NaN         NaN          NaN
#
#    Atari ST Rank Board Game Rank  Children's Game Rank  Commodore 64 Rank  \
# 0            NaN             327                   NaN                NaN
# 1            NaN             151                   NaN                NaN
# 2            NaN              74                   NaN                NaN
#
#    Customizable Rank  ...                      suggested_language_dependence  \
# 0                NaN  ...  [OrderedDict([('@level', '36'), ('@value', 'No...
# 1                NaN  ...  [OrderedDict([('@level', '1'), ('@value', 'No ...
# 2                NaN  ...  [OrderedDict([('@level', '21'), ('@value', 'No...
#
#                                suggested_num_players  \
# 0  [OrderedDict([('@numplayers', '1'), ('result',...
# 1  [OrderedDict([('@numplayers', '1'), ('result',...
# 2  [OrderedDict([('@numplayers', '1'), ('result',...
#
#                                  suggested_playerage  \
# 0  [OrderedDict([('@value', '2'), ('@numvotes', '...
# 1  [OrderedDict([('@value', '2'), ('@numvotes', '...
# 2  [OrderedDict([('@value', '2'), ('@numvotes', '...
#
#                                            thumbnail  trading       type  \
# 0  https://cf.geekdo-images.com/thumb/img/g8LvJsd...     1685  boardgame
# 1  https://cf.geekdo-images.com/thumb/img/kqE4YJS...     1477  boardgame
# 2  https://cf.geekdo-images.com/thumb/img/HEKrtpT...     1977  boardgame
#
#    usersrated wanting  wishing  yearpublished
# 0       85332     453     4729           1995
# 1       85052     498     5403           2000
# 2       83486     614     7655           2008
#
# [3 rows x 56 columns]

# %%
data.tail(3)
# Out:
#        Unnamed: 0  Abstract Game Rank  Accessory Rank  Amiga Rank  \
# 17060       17060                 NaN             NaN         NaN
# 17061       17061                 NaN             NaN         NaN
# 17062       17062                 NaN             NaN         NaN
#
#        Arcade Rank  Atari ST Rank Board Game Rank  Children's Game Rank  \
# 17060          NaN            NaN           14315                   NaN
# 17061          NaN            NaN           14317                   NaN
# 17062          NaN            NaN           15543                   NaN
#
#        Commodore 64 Rank  Customizable Rank  ...  \
# 17060                NaN                NaN  ...
# 17061                NaN                NaN  ...
# 17062                NaN                NaN  ...
#
#        suggested_language_dependence  \
# 17060                            NaN
# 17061                            NaN
# 17062                            NaN
#
#                                    suggested_num_players  \
# 17060  [OrderedDict([('@numplayers', '1'), ('result',...
# 17061  [OrderedDict([('@numplayers', '1'), ('result',...
# 17062  [OrderedDict([('@numplayers', '1'), ('result',...
#
#                                      suggested_playerage  \
# 17060                                                NaN
# 17061                                                NaN
# 17062  [OrderedDict([('@value', '2'), ('@numvotes', '...
#
#                                                thumbnail  trading       type  \
# 17060  https://cf.geekdo-images.com/thumb/img/w-qK2q5...       12  boardgame
# 17061  https://cf.geekdo-images.com/thumb/img/dgf5MIp...       12  boardgame
# 17062  https://cf.geekdo-images.com/thumb/img/k3V6l7k...        2  boardgame
#
#        usersrated wanting  wishing  yearpublished
# 17060          30       2        3           1986
# 17061          30       7        6           1997
# 17062          30       1        5           1999
#
# [3 rows x 56 columns]

# %% [markdown]
# ### Data Exploration

# %% [markdown]
# Se eliminan variables con valor NA y no relevantes para facilitar la construcción del modelo.

# %%
data.drop(['Unnamed: 0', "bayesaverage",'Abstract Game Rank', 'Accessory Rank', 'Amiga Rank','Arcade Rank', 'Atari ST Rank', 
            'Board Game Rank',"Children's Game Rank", 'Commodore 64 Rank', 'Customizable Rank','Family Game Rank', 
            'Party Game Rank', 'RPG Item Rank','Strategy Game Rank', 'Thematic Rank', 'Video Game Rank',
            'War Game Rank', 'alternate','boardgameartist', 'boardgamecategory','boardgamecompilation', 
            'boardgamedesigner', 'boardgameexpansion','boardgamefamily', 'boardgameimplementation', 
            'boardgameintegration','boardgamemechanic', 'boardgamepublisher', 'description', 
            'image','median','stddev', 'suggested_language_dependence','suggested_num_players', 
            'suggested_playerage', 'thumbnail',"primary","id","maxplaytime",
            "minplaytime"], axis=1, inplace=True)

# %% [markdown]
# Se eliminan los valores ausentes y solo se consideran los juegos de mesa con valoración de más de 30 usuarios.

# %%
data = data.dropna(axis=0)
data = data[data['usersrated']>30]

# %% [markdown]
# El dataset tiene los siguientes atributos para el análisis:

# %%
list(data)
# Out:
# ['average',
#  'averageweight',
#  'maxplayers',
#  'minage',
#  'minplayers',
#  'numcomments',
#  'numweights',
#  'owned',
#  'playingtime',
#  'trading',
#  'type',
#  'usersrated',
#  'wanting',
#  'wishing',
#  'yearpublished']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16848 entries, 0 to 17048
# Data columns (total 15 columns):
# average          16848 non-null float64
# averageweight    16848 non-null float64
# maxplayers       16848 non-null int64
# minage           16848 non-null int64
# minplayers       16848 non-null int64
# numcomments      16848 non-null int64
# numweights       16848 non-null int64
# owned            16848 non-null int64
# playingtime      16848 non-null int64
# trading          16848 non-null int64
# type             16848 non-null object
# usersrated       16848 non-null int64
# wanting          16848 non-null int64
# wishing          16848 non-null int64
# yearpublished    16848 non-null int64
# dtypes: float64(2), int64(12), object(1)
# memory usage: 2.1+ MB

# %%
data.describe()
# Out:
#             average  averageweight    maxplayers        minage    minplayers  \
# count  16848.000000   16848.000000  16848.000000  16848.000000  16848.000000
# mean       6.355177       2.009294      5.548018      9.542616      2.041845
# std        0.908756       0.838438     15.876110      3.650856      0.675861
# min        1.052540       0.000000      0.000000      0.000000      0.000000
# 25%        5.784910       1.333300      4.000000      8.000000      2.000000
# 50%        6.386840       2.000000      4.000000     10.000000      2.000000
# 75%        6.960120       2.564450      6.000000     12.000000      2.000000
# max        9.597140       5.000000    999.000000     25.000000     10.000000
#
#         numcomments    numweights          owned    playingtime       trading  \
# count  16848.000000  16848.000000   16848.000000   16848.000000  16848.000000
# mean     207.447590     53.873457    1287.183879      97.442842     43.292082
# std      619.702629    208.763566    4337.404143    1089.857351     95.558135
# min        0.000000      0.000000       3.000000       0.000000      0.000000
# 25%       25.000000      5.000000     147.000000      30.000000      6.000000
# 50%       51.000000     11.000000     306.000000      45.000000     14.000000
# 75%      137.000000     29.000000     822.000000      90.000000     40.000000
# max    16330.000000   6950.000000  125254.000000  120000.000000   2247.000000
#
#          usersrated       wanting       wishing  yearpublished
# count  16848.000000  16848.000000  16848.000000   16848.000000
# mean     789.960173     43.469967    199.277125    1984.043388
# std     3103.369833    120.465389    645.746221     206.884724
# min       31.000000      0.000000      0.000000   -3500.000000
# 25%       57.000000      3.000000     12.000000    1999.000000
# 50%      122.000000      9.000000     34.000000    2009.000000
# 75%      381.000000     29.000000    115.000000    2015.000000
# max    85332.000000   2074.000000  13318.000000    2020.000000

# %% [markdown]
# #### Histogramas

# %%
# Source: https://stackoverflow.com/questions/43638851/pandas-histogram-plot-with-kde
data_hist =data.drop(["type"], 
           axis=1)
k = len(data_hist.columns)
n = 2
m = (k - 1) // n + 1
fig, axes = plt.subplots(m, n, figsize=(n * 5, m * 3))
for i, (name, col) in enumerate(data_hist.iteritems()):
    r, c = i // n, i % n
    ax = axes[r, c]
    col.hist(ax=ax)
    ax2 = col.plot.kde(ax=ax, secondary_y=True, title=name)
    ax2.set_ylim(0)

fig.tight_layout()

# %%
fig = plt.figure()
sns.set(color_codes="True")
sns.distplot(data['average'], kde=True);
plt.xlabel('Average Rating')
plt.ylabel('% Observations')
plt.title('Target variable Average Rating distribution')
plt.tight_layout()
plt.show();

# %% [markdown]
# A continuación, se calculan los valores medios y desviación típica.

# %%
y_mean = data['average'].mean()
y_std = data['average'].std()
print('Average Rating Mean {}'.format(y_mean))
print('Average Rating Standard Deviation {} \n'.format(y_std))
# Out:
# Average Rating Mean 6.355177413342848
# Average Rating Standard Deviation 0.9087563200891718

# %% [markdown]
# Se genera la matriz de correlación.

# %%
corr_matrix = data.corr()
type_dummy = pd.get_dummies(data.type)
data = pd.concat([data, type_dummy], axis = 1)
mask = np.zeros_like(corr_matrix, dtype=np.bool)
mask[np.triu_indices_from(mask)]= True

# %%
f, ax = plt.subplots(figsize=(15,15)) 
heatmap = sns.heatmap(corr_matrix, 
                      mask = mask,
                      square = True,
                      linewidths = .5,
                      cmap = 'coolwarm',
                      cbar_kws = {'shrink': .4, 
                                'ticks' : [-1, -.5, 0, 0.5, 1]},
                      vmin = -1, 
                      vmax = 1,
                      annot = True,
                      annot_kws = {'size': 12})
#add the column names as labels
ax.set_yticklabels(corr_matrix.columns, rotation = 0)
ax.set_xticklabels(corr_matrix.columns)
sns.set_style({'xtick.bottom': True}, {'ytick.left': True})

# %% [markdown]
# Caracteristicas de la matriz de correlación:
# * Number Weight: es una métrica de la comunidad BoardGameGeek que estima el grado de dificultad de comprender el juego de mesa. Mientras menor el weight más fácil el juego. Como muestra la matriz hay alta correlación con las variables número de comentarios, intercambios, compras y usuarios que califican, demuestra que mientras más fácil el juego existe mayor compra y reviews sobre él.
# * Wanting: es el número de usuarios que revisaron el juego por la página. Tiene alta relación con los comentarios y compras lo que significa que por cada revisión hay alta probabilidad de compra.
# * Wishing: es el número de usuarios que el juego en su wishlist. Tiene alta relación con wanting, adicionalmente con comentarios y compras, se puede asociar a que cada revisión de un juego puede llevar a agregarlo en la lista de deseos y posible compra.

# %% [markdown]
# Se generan los histogramas y gráficos de dispersión de cada variable mediante la libreria seaborn (pairplot).

# %%
g = sns.pairplot(data)
for i, j in zip(*np.triu_indices_from(g.axes, 1)):
    g.axes[i, j].set_visible(False)

# %% [markdown]
# Se extraen las variables con alta correlación para simplificar el modelo.
# Se simula grupos de datos mediante la libreria KMeans.

# %%
data_k = data
data_k["average"].astype('float', copy=False, inplace=True)
data_k.drop(["type","numcomments","numweights"], 
           axis=1, inplace=True)
cluster = KMeans(n_clusters=5)
cluster.fit(data_k)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %% [markdown]
# El siguiente gráfico compara la desviación típica y media. Muestra que varios juegos de mesa son similares (los grupos verde, naranja y azul). El grupo que se ubica más a la izquierda (azul) tiene dos casos con alta variabilidad que los otros. Sucede algo similar con el grupo de la derecha (Rojo Vino).

# %%
fig=plt.figure()
plt.style.use('fivethirtyeight')
plt.scatter(x=data_k.apply(np.mean, axis=1), 
            y=data_k.apply(np.std, axis=1),
            c=cluster.labels_, cmap='jet');
plt.xlabel('Observation Mean')
plt.ylabel('Observation SD')
plt.title('Kmeans clustering of value mean vs standard deviation')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Data Wrangling

# %% [markdown]
# Sólo se utilizará la información de los juegos publicados desde 1991.

# %%
data = data[(data['yearpublished'] > 1990)]
print(data.shape)
data.head(5)
# Out:
# (14222, 13)
#    average  averageweight  maxplayers  minage  minplayers   owned  \
# 0  7.19118         2.3399           4      10           3  125254
# 1  7.42605         1.9247           5       8           2  121717
# 2  7.63799         2.4220           4       8           2  123067
# 3  7.78118         2.3397           7      10           2   91037
# 4  7.64470         2.3623           4      13           2   88729
#
#    playingtime  trading  usersrated  wanting  wishing  yearpublished  \
# 0          120     1685       85332      453     4729           1995
# 1           45     1477       85052      498     5403           2000
# 2           45     1977       83486      614     7655           2008
# 3           30     1162       69132     1029     9464           2010
# 4           30     1806       68284      571     6703           2008
#
#    boardgame
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# Las variables son cuantitativas, el caso de tipo se convirtió en una variable dummy.

# %%
data.head(5)
# Out:
#    average  averageweight  maxplayers  minage  minplayers   owned  \
# 0  7.19118         2.3399           4      10           3  125254
# 1  7.42605         1.9247           5       8           2  121717
# 2  7.63799         2.4220           4       8           2  123067
# 3  7.78118         2.3397           7      10           2   91037
# 4  7.64470         2.3623           4      13           2   88729
#
#    playingtime  trading  usersrated  wanting  wishing  yearpublished  \
# 0          120     1685       85332      453     4729           1995
# 1           45     1477       85052      498     5403           2000
# 2           45     1977       83486      614     7655           2008
# 3           30     1162       69132     1029     9464           2010
# 4           30     1806       68284      571     6703           2008
#
#    boardgame
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Train and Test Subsets (Supervised Learning)

# %% [markdown]
# Se selecciona los subsets de train y test. Train será el 80% del dataset y Test, el 20% restante, elegidos aleatoriamente.

# %%
data_train = data.sample(frac = 0.8, random_state = 7)
data_test = data.loc[~data.index.isin(data_train.index)]

# %%
print(data_train.shape)
print(data_test.shape)
# Out:
# (11378, 13)
# (2844, 13)

# %%
y_train = data_train.pop('average')
y_test = data_test.pop('average')
print(y_train.dtype)
print(y_train.shape)
# Out:
# float64
# (11378,)

# %%
print(y_test.dtype)
print(y_test.shape)
# Out:
# float64
# (2844,)

# %% [markdown]
# ### Model Selection

# %% [markdown]
# Se define el modelo como una regression lineal, y se ajusta el subset de Train.

# %%
lr = LinearRegression()

# %% [markdown]
# #### Ridge Regularization

# %%
data_standardized = preprocessing.scale(data_train)

# %%
ridge_cv = linear_model.RidgeCV(cv=10, normalize=False)

# %%
ridge_cv.fit(data_standardized, y_train)
# Out:
# RidgeCV(alphas=array([ 0.1,  1. , 10. ]), cv=10, fit_intercept=True,
#         gcv_mode=None, normalize=False, scoring=None, store_cv_values=False)

# %%
alpha_ridge = ridge_cv.alpha_
ridge_coef = ridge_cv.coef_
print(ridge_coef)
# Out:
# [ 0.40445241  0.0087486   0.00553351 -0.03998857  0.39483498  0.01955423
#  -0.10619423 -0.18708603  0.41716204 -0.33500614  0.31031064  0.        ]

# %%
ridge_cv = linear_model.Ridge(alpha=alpha_ridge, random_state = 7)

# %%
ridge_cv.fit(data_standardized, y_train)
# Out:
# Ridge(alpha=10.0, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=7, solver='auto', tol=0.001)

# %%
cv_score_ridge = cross_val_score(ridge_cv, data_standardized,
                                 y_train, cv=10,
                                 scoring='neg_mean_squared_error')
rmse_ridge = np.mean(-cv_score_ridge) ** (0.5)
rmse_ridge
# Out:
# 0.6796300660324781

# %% [markdown]
# #### Lasso Regularization

# %%
lasso_cv = linear_model.LassoCV(cv = 10, normalize = False,
                                verbose = True, random_state = 7)

# %%
lasso_cv.fit(data_standardized, y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................[Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.3s finished
# LassoCV(alphas=None, copy_X=True, cv=10, eps=0.001, fit_intercept=True,
#         max_iter=1000, n_alphas=100, n_jobs=None, normalize=False,
#         positive=False, precompute='auto', random_state=7, selection='cyclic',
#         tol=0.0001, verbose=True)

# %%
alpha_lasso = lasso_cv.alpha_
lasso_coef = lasso_cv.coef_
print(lasso_coef)
# Out:
# [ 0.40414506  0.00436302  0.00181992 -0.03788543  0.12793397  0.01616175
#  -0.06332428 -0.          0.27603634 -0.16311081  0.30782888  0.        ]

# %%
lasso = linear_model.Lasso(alpha = alpha_lasso,
                           random_state = 7)

# %%
lasso.fit(data_standardized, y_train)
# Out:
# Lasso(alpha=0.004153288346813445, copy_X=True, fit_intercept=True,
#       max_iter=1000, normalize=False, positive=False, precompute=False,
#       random_state=7, selection='cyclic', tol=0.0001, warm_start=False)

# %%
cv_score_lasso = cross_val_score(lasso_cv, data_standardized,
                                 y_train, cv = 10,
                                 scoring = 'neg_mean_squared_error',
                                 verbose = 0)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................[Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................[Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................[Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................[Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................[Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................[Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................[Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................[Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................[Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.4s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................[Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.4s finished

# %%
rmse_lasso = np.mean(-cv_score_lasso) ** (0.5)
rmse_lasso
# Out:
# 0.681147284293343

# %% [markdown]
# ### Tuning Parameters

# %% [markdown]
# #### Model Metrics

# %% [markdown]
# Ambos modelos regularizados por Ridge y Lasso tienen resultados similares. Ridge parece más robusto por que provee una solución, en cambio Lasso entrega un conjunto de posibles soluciones.
# A continuación, se calcula la diferencia entre los coeficientes de ambas propuestas.

# %%
difference = np.absolute(np.subtract(lasso_coef, ridge_coef))
print(difference)
# Out:
# [0.00030735 0.00438558 0.00371359 0.00210313 0.26690101 0.00339248
#  0.04286996 0.18708603 0.1411257  0.17189533 0.00248175 0.        ]

# %% [markdown]
# El coeficiente de la variable owned tiene mayor diferencia en las pruebas. Es posible que sea debido a la correlación.
